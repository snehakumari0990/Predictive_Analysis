# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib as plt

# %%
data = {
    "student_id": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "math_marks": [85, 72, 91, 64, 78, 95, 68, 88, 76, 83],
    "science_marks": [89, 75, 94, 70, 82, 92, 71, 85, 79, 87],
    "english_marks": [78, 80, 88, 65, 74, 90, 72, 86, 81, 84],
    "computer_marks": [92, 85, 96, 72, 88, 98, 75, 91, 84, 89]
}
print(data)

# %%
df = pd.DaraFrame(data)

# %%
print(df)
